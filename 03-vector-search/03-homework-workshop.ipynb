# %%
# !pip install dlt[lancedb]==0.5.1a0
# !pip install sentence-transformers
# Out:
# zsh:1: no matches found: dlt[lancedb]==0.5.1a0
# Requirement already satisfied: sentence-transformers in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: numpy in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (0.24.0)
# Requirement already satisfied: Pillow in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.0)
# Requirement already satisfied: networkx in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/cristian.zapata/Documents/zoomcamps/llm-zoomcamp-homeworks/.venv/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv, find_dotenv
# from google.colab import userdata

_ = load_dotenv(find_dotenv(".env"))
# os.environ["SOURCES__REST_API__NOTION__API_KEY"] = ""

os.environ["DESTINATION__LANCEDB__EMBEDDING_MODEL_PROVIDER"] = "sentence-transformers"
os.environ["DESTINATION__LANCEDB__EMBEDDING_MODEL"] = "all-MiniLM-L6-v2"

os.environ["DESTINATION__LANCEDB__CREDENTIALS__URI"] = ".lancedb"

# %%
# !yes | dlt init rest_api lancedb
# Out:
# Looking up the init scripts in https://github.com/dlt-hub/verified-sources.git...
# Cloning and configuring a verified source rest_api (Generic API Source)
# Do you want to proceed? [Y/n]:
# Verified source rest_api was added to your project!
# * See the usage examples and code snippets to copy from rest_api_pipeline.py
# * Add credentials for lancedb and other secrets in ./.dlt/secrets.toml
# * requirements.txt was created. Install it with:
# pip3 install -r requirements.txt
# * Read https://dlthub.com/docs/walkthroughs/create-a-pipeline for more information
# yes: stdout: Broken pipe

# %%
import dlt
from rest_api import RESTAPIConfig, rest_api_source

from dlt.sources.helpers.rest_client.paginators import BasePaginator, JSONResponsePaginator
from dlt.sources.helpers.requests import Response, Request

from dlt.destinations.adapters import lancedb_adapter

# %%
from datetime import datetime, timezone

class PostBodyPaginator(BasePaginator):
    def __init__(self):
        super().__init__()
        self.cursor = None

    def update_state(self, response: Response) -> None:
        # Assuming the API returns an empty list when no more data is available
        if not response.json():
            self._has_next_page = False
        else:
            self.cursor = response.json().get("next_cursor")
            if self.cursor is None:
                self._has_next_page = False

    def update_request(self, request: Request) -> None:
        if request.json is None:
            request.json = {}

        # Add the cursor to the request body
        request.json["start_cursor"] = self.cursor

@dlt.resource(name="employee_handbook")
def rest_api_notion_resource():
    notion_config: RESTAPIConfig = {
        "client": {
            "base_url": "https://api.notion.com/v1/",
            "auth": {
                "token": dlt.secrets["sources.rest_api.notion.api_key"]
            },
            "headers":{
            "Content-Type": "application/json",
            "Notion-Version": "2022-06-28"
            }
        },
        "resources": [
            {
                "name": "search",
                "endpoint": {
                    "path": "search",
                    "method": "POST",
                    "paginator": PostBodyPaginator(),
                    "json": {
                        "query": "Homework",
                        "sort": {
                            "direction": "ascending",
                            "timestamp": "last_edited_time"
                        }
                    },
                    "data_selector": "results"
                }
            },
            {
                "name": "page_content",
                "endpoint": {
                    "path": "blocks/{page_id}/children",
                    "paginator": JSONResponsePaginator(),
                    "params": {
                        "page_id": {
                            "type": "resolve",
                            "resource": "search",
                            "field": "id"
                        }
                    },
                }
            }
        ]
    }

    yield from rest_api_source(notion_config,name="employee_handbook")

def extract_page_content(response):
    block_id = response["id"]
    last_edited_time = response["last_edited_time"]
    block_type = response.get("type", "Not paragraph")
    if block_type != "paragraph":
        content = ""
    else:
        try:
            content = response["paragraph"]["rich_text"][0]["plain_text"]
        except IndexError:
            content = ""
    return {
        "block_id": block_id,
        "block_type": block_type,
        "content": content,
        "last_edited_time": last_edited_time,
        "inserted_at_time": datetime.now(timezone.utc)
    }

@dlt.resource(
    name="employee_handbook",
    write_disposition="merge",
    primary_key="block_id",
    columns={"last_edited_time":{"dedup_sort":"desc"}}
    )
def rest_api_notion_incremental(
    last_edited_time = dlt.sources.incremental("last_edited_time", initial_value="2024-06-26T08:16:00.000Z",primary_key=("block_id"))
):
    # last_value = last_edited_time.last_value
    # print(last_value)

    for block in rest_api_notion_resource.add_map(extract_page_content):
        if not(len(block["content"])):
            continue
        yield block

def load_notion() -> None:
    pipeline = dlt.pipeline(
        pipeline_name="company_policies",
        destination="lancedb",
        dataset_name="notion_pages",
        # full_refresh=True
    )

    load_info = pipeline.run(
        lancedb_adapter(
            rest_api_notion_incremental,
            embed="content"
        ),
        table_name="homework",
        write_disposition="merge"
    )
    print(load_info)

load_notion()
# Out:
# _dlt_pipeline_state
# [{'name': 'version', 'data_type': 'bigint', 'nullable': False}, {'name': 'engine_version', 'data_type': 'bigint', 'nullable': False}, {'name': 'pipeline_name', 'data_type': 'text', 'nullable': False}, {'name': 'state', 'data_type': 'text', 'nullable': False}, {'name': 'created_at', 'data_type': 'timestamp', 'nullable': False}, {'name': 'version_hash', 'data_type': 'text', 'nullable': True}, {'name': '_dlt_load_id', 'data_type': 'text', 'nullable': False}, {'name': '_dlt_id', 'data_type': 'text', 'nullable': False, 'unique': True}]
# _dlt_loads
# [{'name': 'load_id', 'data_type': 'text', 'nullable': False}, {'name': 'schema_name', 'data_type': 'text', 'nullable': True}, {'name': 'status', 'data_type': 'bigint', 'nullable': False}, {'name': 'inserted_at', 'data_type': 'timestamp', 'nullable': False}, {'name': 'schema_version_hash', 'data_type': 'text', 'nullable': True}]
# _dlt_version
# [{'name': 'version', 'data_type': 'bigint', 'nullable': False}, {'name': 'engine_version', 'data_type': 'bigint', 'nullable': False}, {'name': 'inserted_at', 'data_type': 'timestamp', 'nullable': False}, {'name': 'schema_name', 'data_type': 'text', 'nullable': False}, {'name': 'version_hash', 'data_type': 'text', 'nullable': False}, {'name': 'schema', 'data_type': 'text', 'nullable': False}]
# homework
# [{'name': 'block_id', 'nullable': False, 'primary_key': True, 'data_type': 'text'}, {'name': 'block_type', 'data_type': 'text', 'nullable': True}, {'name': 'content', 'x-lancedb-embed': True, 'data_type': 'text', 'nullable': True}, {'dedup_sort': 'desc', 'name': 'last_edited_time', 'data_type': 'timestamp', 'nullable': True}, {'name': 'inserted_at_time', 'data_type': 'timestamp', 'nullable': True}, {'name': '_dlt_load_id', 'data_type': 'text', 'nullable': False}, {'name': '_dlt_id', 'data_type': 'text', 'nullable': False, 'unique': True}]
# UPLOAD
# Pipeline company_policies load step completed in 12.66 seconds
# 1 load package(s) were loaded to destination LanceDB and into dataset notion_pages
# The LanceDB destination used <dlt.destinations.impl.lancedb.configuration.LanceDBCredentials object at 0x11e88d010> location to store data
# Load package 1721402808.825918 is LOADED and contains no failed jobs

# %%
import lancedb

db = lancedb.connect(".lancedb")
dbtable = db.open_table("notion_pages___homework")

dbtable.to_pandas()
# Out:
#                                     id__  \
# 0   c69f1ecf-7b02-5810-8286-3f42659ae9d4
# 1   f2c18ac0-50f5-5b72-a871-dc5a46780353
# 2   4553193e-c655-54df-9a33-cfc570bf34d0
# 3   791be1a1-6c67-530d-87ab-bd9912500ea5
# 4   a83497f4-922c-5d62-bab1-53804e93c811
# 5   434b71e9-a11a-519d-a9fe-e3ade78d47d6
# 6   17816363-54b7-5ba7-b8d5-06d871a25414
# 7   2a434cf9-09d9-5514-a88b-02977f2f953e
# 8   5f9384fa-7f98-5f52-a06e-05b05f42f69a
# 9   42af72f6-9db7-54a2-87b2-d466169078ff
# 10  8bfc36ce-cdb0-5792-bd70-d12ff22fc227
# 11  b1737a97-6dca-564c-a169-78e306a5e124
# 12  896f7ed8-e918-54f3-a7b8-565d53d6d22b
# 13  3557e3dd-de5b-51b9-bdee-b53ba588ed60
# 14  c51f99bf-5057-572e-bf9e-25dc03014c79
# 15  0317522c-a6db-59e8-ba5f-5ff0dc960d2e
# 16  4d0eb4d7-f0ad-517c-8165-7eb7932ea0ed
#
#                                              vector__  \
# 0   [-0.024265641, 0.047460828, -0.011796464, 0.06...
# 1   [-0.049661566, 0.10853514, -0.009762564, -0.03...
# 2   [-0.06316319, 0.17331503, 0.025351701, -0.0191...
# 3   [-0.10974315, 0.10586078, 0.003290593, -0.0213...
# 4   [0.052423317, -0.064575925, 0.06586298, 0.0145...
# 5   [0.00052332686, -0.054883406, 0.04357338, -0.0...
# 6   [0.038026303, -0.021509668, 0.047527798, 0.064...
# 7   [-0.058588095, -0.07540447, 0.033775184, 0.009...
# 8   [-0.013599253, 0.0047530388, 0.024835164, 0.01...
# 9   [0.03206088, 0.024244618, 0.008471353, 0.03179...
# 10  [-0.013155323, 0.00838246, 0.017044391, 0.0514...
# 11  [0.027987454, 0.06734363, 0.039806414, 0.00774...
# 12  [0.03252609, 0.008159483, 0.08443562, 0.055641...
# 13  [-0.007314079, 0.014710699, -0.019091198, 0.02...
# 14  [-0.031538427, 0.034259956, -0.027282648, 0.02...
# 15  [-0.017366938, 0.06079059, 0.015769992, -0.014...
# 16  [0.033655442, 0.03574241, 0.039310936, 0.00372...
#
#                                 block_id block_type  \
# 0   a8196881-ae94-4767-8767-92fe1a327d24  paragraph
# 1   31fcbf26-2ca5-468a-8af8-d7eb4c2db8c8  paragraph
# 2   da7721fd-3d0f-4c04-bc5e-825ad60bed1c  paragraph
# 3   ff36dcf3-5faa-40b4-ad8e-92fdc952201e  paragraph
# 4   a1ff9697-4bb6-4f1e-b464-dda296dbd307  paragraph
# 5   e4ec9f4d-b687-4c28-a80d-985bfabcc2ba  paragraph
# 6   e6e550dc-b59e-4928-abd7-07eace948681  paragraph
# 7   a269d0ca-ce14-481b-a5f4-9192d6840d6e  paragraph
# 8   5b65f3e7-0a37-429a-818d-f99b53755ebd  paragraph
# 9   b27f7d80-f2f1-460e-aa0c-b8e770cf050a  paragraph
# 10  cf2c7276-9d6d-4611-97ef-e7707a668176  paragraph
# 11  79fd88bb-894c-4db3-961e-f2e9fa571399  paragraph
# 12  0b5f3660-7867-41ea-ae25-95585c3bb34e  paragraph
# 13  3153e9cf-44bf-4ec1-b835-67d37731f9bc  paragraph
# 14  b9d67165-1028-4edc-841b-fe2fd4cf0cf7  paragraph
# 15  72d2f585-a1b4-461e-ad88-45d9e3346425  paragraph
# 16  b1a9a976-eef2-4c99-9f57-3e5adb873d1f  paragraph
#
#                                               content  \
# 0   We owe our success to our employees. To show o...
# 1   We want to ensure that private information abo...
# 2   Employee health is important to us. We don’t d...
# 3   Our company is dedicated to maintaining a safe...
# 4   If your job doesn’t require you to be present ...
# 5   Remote working refers to working from a non-of...
# 6   There are some expenses that we will pay direc...
# 7   Our company operates between 9 a.m. to 7 p.m. ...
# 8   In this section, we are going to be covering i...
# 9   Our company observes the following holidays: N...
# 10  These holidays are considered “off-days” for m...
# 11  Employees who are unable to work due to illnes...
# 12  Losing a loved one is traumatizing. If this ha...
# 13  In accordance with German law, we offer a comp...
# 14  We recognize the vital role that fathers and p...
# 15  Our company’s official dress code is Business ...
# 16  If you want to invite a visitor to our offices...
#
#             last_edited_time                 inserted_at_time  \
# 0  2024-07-05 22:34:00+00:00 2024-07-19 15:26:49.812546+00:00
# 1  2024-07-05 22:38:00+00:00 2024-07-19 15:26:49.817908+00:00
# 2  2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.818251+00:00
# 3  2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.818534+00:00
# 4  2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.818820+00:00
# 5  2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.819111+00:00
# 6  2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.819406+00:00
# 7  2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.819718+00:00
# 8  2024-07-05 23:33:00+00:00 2024-07-19 15:26:49.820012+00:00
# 9  2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.820200+00:00
# 10 2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.820369+00:00
# 11 2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.820589+00:00
# 12 2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.820855+00:00
# 13 2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.821209+00:00
# 14 2024-07-05 22:52:00+00:00 2024-07-19 15:26:49.821494+00:00
# 15 2024-07-05 22:54:00+00:00 2024-07-19 15:26:49.821685+00:00
# 16 2024-07-05 22:56:00+00:00 2024-07-19 15:26:49.821861+00:00
#
#          _dlt_load_id         _dlt_id
# 0   1721402808.825918  fEKvjIU23SoMeA
# 1   1721402808.825918  wNrT/iOS1fzMQQ
# 2   1721402808.825918  pQ+4XptYNAcQ6g
# 3   1721402808.825918  lbfkhXPNhKD65w
# 4   1721402808.825918  KAZ2RP9XXOt4KA
# 5   1721402808.825918  rmS5Fingvur7ww
# 6   1721402808.825918  gME6qYTG9ZC1CA
# 7   1721402808.825918  3ZDL0kSLrFqg8A
# 8   1721402808.825918  z77Pl5CP2g6W7w
# 9   1721402808.825918  UwIQKVETmQ7KLQ
# 10  1721402808.825918  Rv2Wg/11LsMoSw
# 11  1721402808.825918  BvzTO4u3CdpQ5w
# 12  1721402808.825918  yVwp1jot1dE4ag
# 13  1721402808.825918  ntgnMwFBupAJGA
# 14  1721402808.825918  LjtY8ASiYgEkiA
# 15  1721402808.825918  mZ9XueahLAlRVg
# 16  1721402808.825918  eBk7KfkKy6E5YA

# %%
db.table_names()
# Out:
# ['notion_pages____dlt_loads',
#  'notion_pages____dlt_pipeline_state',
#  'notion_pages____dlt_version',
#  'notion_pages___dltSentinelTable',
#  'notion_pages___homework']
